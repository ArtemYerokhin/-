# %% [markdown]
# # Восстановление золота из руды
# ## Описание проекта
# Компания разрабатывает решения для эффективной работы промышленных предприятий. Представлены данные с параметрами добычи и очистки золотосодержащей руды. Необходимо построить модель машинного обучения.
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
# ## Стадии технологического процесса:
# 1. *Флотация*.
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
# 2. *Очистка*.
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
# <img src= "https://pictures.s3.yandex.net/resources/viruchka_1576238830.jpg" alt="Scheme" style="width: 600px;"/>
#
# ## Описание данных
#
# **Технологический процесс**
#
# `Rougher feed` — исходное сырье
#
# `Rougher additions` (или `reagent additions`) — флотационные реагенты: Xanthate, Sulphate, Depressant
#
#     Xanthate — ксантогенат (промотер, или активатор флотации);
#
#     Sulphate — сульфат (на данном производстве сульфид натрия);
#
#     Depressant — депрессант (силикат натрия).
#
# `Rougher process` (англ. «грубый процесс») — флотация
#
# `Rougher tails` — отвальные хвосты
#
# `Float banks` — флотационная установка
#
# `Cleaner process` — очистка
#
# `Rougher Au` — черновой концентрат золота
#
# `Final Au` — финальный концентрат золота
#
# **Параметры этапов**
#
# `air amount` — объём воздуха
#
# `fluid levels` — уровень жидкости
#
# `feed size` — размер гранул сырья
#
# `feed rate` — скорость подачи
#
# ## Наименование признаков
# Наименование признаков должно быть такое:
# `этап`.`тип_параметра`.`название_параметра`
#
# Возможные значения для блока `этап`:
#
# `rougher` — флотация
#
# `primary_cleaner` — первичная очистка
#
# `secondary_cleaner` — вторичная очистка
#
# `final` — финальные характеристики
#
# Возможные значения для блока `тип_параметра`:
#
# `input` — параметры сырья
#
# `output` — параметры продукта
#
# `state` — параметры, характеризующие текущее состояние этапа
#
# `calculation` — расчётные характеристики
# ## Последовательность шагов проекта
# 1. Загрузка и исследование датасетов.
# 2. Исследовательский анализ данных.
# 3. Построение и проверка моделей.
# 4. Выбор и испытание лучшей модели.
# ## 1. Загрузка и исследование данных.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.dummy import DummyRegressor

plt.style.use('dark_background')

# %%
train_df.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                55.486599                          11.986616
# 1                57.278666                          11.971193
# 2                57.510649                          11.920603
# 3                57.792734                          11.630094
# 4                56.047189                          10.957755
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  ...  \
# 0                            6.007990                       999.706909  ...
# 1                            6.005766                      1000.286398  ...
# 2                            6.197377                       999.719565  ...
# 3                            6.203177                       999.814770  ...
# 4                            6.198826                       999.678690  ...
#
#    secondary_cleaner.output.tail_sol  final.output.concentrate_au  \
# 0                           8.764648                    42.192020
# 1                           9.001494                    42.701629
# 2                           8.842896                    42.657501
# 3                           9.122857                    42.689819
# 4                           8.871028                    42.774141
#
#    final.output.concentrate_ag  final.output.concentrate_pb  \
# 0                     6.055403                     9.889648
# 1                     6.029369                     9.968944
# 2                     6.055926                    10.213995
# 3                     6.047977                     9.977019
# 4                     6.148599                    10.142511
#
#    final.output.concentrate_sol  final.output.recovery  final.output.tail_au  \
# 0                      5.507324              70.541216              2.143149
# 1                      5.257781              69.266198              2.224930
# 2                      5.383759              68.116445              2.257889
# 3                      4.858634              68.347543              2.146849
# 4                      4.939416              66.927016              2.055292
#
#    final.output.tail_ag  final.output.tail_pb  final.output.tail_sol
# 0             10.411962              0.895447              16.904297
# 1             10.462676              0.927452              16.634514
# 2             10.507046              0.953716              16.208849
# 3             10.422762              0.883763              16.532835
# 4             10.360302              0.792826              16.525686
#
# [5 rows x 87 columns]

# %%
test_df.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2017-12-09 14:59:59               4.365491               6.158718
# 1  2017-12-09 15:59:59               4.362781               6.048130
# 2  2017-12-09 16:59:59               5.081681               6.082745
# 3  2017-12-09 17:59:59               5.145949               6.084374
# 4  2017-12-09 18:59:59               5.735249               6.165220
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               3.875727               39.135119               555.820208
# 1               3.902537               39.713906               544.731687
# 2               4.564078               37.208683               558.155110
# 3               4.768124               36.808874               539.713765
# 4               4.512346               37.810642               558.713584
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                94.544358                           6.146982
# 1               123.742430                           6.210119
# 2                82.610855                           7.363824
# 3                77.984784                           6.927072
# 4                86.434874                           7.823471
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  ...  \
# 0                            9.308612                      1196.238112  ...
# 1                            9.297709                      1201.904177  ...
# 2                            9.003562                      1200.826926  ...
# 3                            8.955597                      1199.292489  ...
# 4                            7.490356                      1198.005449  ...
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 23.018622
# 1                                 23.024963
# 2                                 22.993827
# 3                                 23.032807
# 4                                 23.001911
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -500.492702
# 1                                 -501.153409
# 2                                 -501.559663
# 3                                 -501.287889
# 4                                 -499.947838
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 20.020205
# 1                                 20.054122
# 2                                 20.029144
# 3                                 19.977466
# 4                                 20.023735
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -500.220296
# 1                                 -500.314711
# 2                                 -500.000662
# 3                                 -500.159903
# 4                                 -499.713680
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                 17.963512
# 1                                 17.979515
# 2                                 18.012723
# 3                                 17.980463
# 4                                 17.990955
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -499.939490
# 1                                 -499.272871
# 2                                 -500.024764
# 3                                 -500.504602
# 4                                 -500.334769
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                 12.990306
# 1                                 12.992404
# 2                                 13.016445
# 3                                 12.949071
# 4                                 13.007523
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.080993
# 1                                 -499.976268
# 2                                 -500.058432
# 3                                 -500.009937
# 4                                 -499.968459
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 19.990336
# 1                                 20.013986
# 2                                 19.973767
# 3                                 20.010332
# 4                                 19.995999
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -499.191575
# 1                                 -500.625471
# 2                                 -501.394155
# 3                                 -508.337973
# 4                                 -499.788805
#
# [5 rows x 53 columns]

# %%
full_df.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                55.486599                          11.986616
# 1                57.278666                          11.971193
# 2                57.510649                          11.920603
# 3                57.792734                          11.630094
# 4                56.047189                          10.957755
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  ...  \
# 0                            6.007990                       999.706909  ...
# 1                            6.005766                      1000.286398  ...
# 2                            6.197377                       999.719565  ...
# 3                            6.203177                       999.814770  ...
# 4                            6.198826                       999.678690  ...
#
#    secondary_cleaner.output.tail_sol  final.output.concentrate_au  \
# 0                           8.764648                    42.192020
# 1                           9.001494                    42.701629
# 2                           8.842896                    42.657501
# 3                           9.122857                    42.689819
# 4                           8.871028                    42.774141
#
#    final.output.concentrate_ag  final.output.concentrate_pb  \
# 0                     6.055403                     9.889648
# 1                     6.029369                     9.968944
# 2                     6.055926                    10.213995
# 3                     6.047977                     9.977019
# 4                     6.148599                    10.142511
#
#    final.output.concentrate_sol  final.output.recovery  final.output.tail_au  \
# 0                      5.507324              70.541216              2.143149
# 1                      5.257781              69.266198              2.224930
# 2                      5.383759              68.116445              2.257889
# 3                      4.858634              68.347543              2.146849
# 4                      4.939416              66.927016              2.055292
#
#    final.output.tail_ag  final.output.tail_pb  final.output.tail_sol
# 0             10.411962              0.895447              16.904297
# 1             10.462676              0.927452              16.634514
# 2             10.507046              0.953716              16.208849
# 3             10.422762              0.883763              16.532835
# 4             10.360302              0.792826              16.525686
#
# [5 rows x 87 columns]

# %% [markdown]
# По первым строкам данных видно, что в тестовой выборке отсутствует 34 столбца, которые есть в других датасетах. Посмотрим, что это за колонки

# %%
set(train_df.columns) - set(test_df.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_au',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_au',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol'}

# %% [markdown]
# Отсутствующие данные относятся к характеристикам продукта стадий переработки и расчетным характеристикам, т.к. они недоступны во время процесса. Нужно сохранить их в переменную для исключения из обучения модели в дальнейшем

# %%
missing_columns = list(set(train_df.columns) - set(test_df.columns))

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14579 entries, 0 to 14578
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14579 non-null  object
#  1   rougher.input.feed_au                               14579 non-null  float64
#  2   rougher.input.feed_ag                               14579 non-null  float64
#  3   rougher.input.feed_pb                               14507 non-null  float64
#  4   rougher.input.feed_sol                              14502 non-null  float64
#  5   rougher.input.feed_rate                             14572 non-null  float64
#  6   rougher.input.feed_size                             14478 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   14548 non-null  float64
#  8   rougher.input.floatbank10_xanthate                  14572 non-null  float64
#  9   rougher.state.floatbank10_a_air                     14579 non-null  float64
#  10  rougher.state.floatbank10_a_level                   14579 non-null  float64
#  11  rougher.state.floatbank10_b_air                     14579 non-null  float64
#  12  rougher.state.floatbank10_b_level                   14579 non-null  float64
#  13  rougher.state.floatbank10_c_air                     14579 non-null  float64
#  14  rougher.state.floatbank10_c_level                   14579 non-null  float64
#  15  rougher.state.floatbank10_d_air                     14579 non-null  float64
#  16  rougher.state.floatbank10_d_level                   14579 non-null  float64
#  17  rougher.state.floatbank10_e_air                     14150 non-null  float64
#  18  rougher.state.floatbank10_e_level                   14579 non-null  float64
#  19  rougher.state.floatbank10_f_air                     14579 non-null  float64
#  20  rougher.state.floatbank10_f_level                   14579 non-null  float64
#  21  rougher.input.floatbank11_sulfate                   14543 non-null  float64
#  22  rougher.input.floatbank11_xanthate                  14172 non-null  float64
#  23  rougher.calculation.sulfate_to_au_concentrate       14578 non-null  float64
#  24  rougher.calculation.floatbank10_sulfate_to_au_feed  14578 non-null  float64
#  25  rougher.calculation.floatbank11_sulfate_to_au_feed  14578 non-null  float64
#  26  rougher.calculation.au_pb_ratio                     14579 non-null  float64
#  27  rougher.output.concentrate_au                       14579 non-null  float64
#  28  rougher.output.concentrate_ag                       14579 non-null  float64
#  29  rougher.output.concentrate_pb                       14579 non-null  float64
#  30  rougher.output.concentrate_sol                      14561 non-null  float64
#  31  rougher.output.recovery                             14579 non-null  float64
#  32  rougher.output.tail_au                              14579 non-null  float64
#  33  rougher.output.tail_ag                              14578 non-null  float64
#  34  rougher.output.tail_pb                              14579 non-null  float64
#  35  rougher.output.tail_sol                             14579 non-null  float64
#  36  primary_cleaner.input.sulfate                       14556 non-null  float64
#  37  primary_cleaner.input.depressant                    14551 non-null  float64
#  38  primary_cleaner.input.feed_size                     14579 non-null  float64
#  39  primary_cleaner.input.xanthate                      14518 non-null  float64
#  40  primary_cleaner.state.floatbank8_a_air              14576 non-null  float64
#  41  primary_cleaner.state.floatbank8_a_level            14579 non-null  float64
#  42  primary_cleaner.state.floatbank8_b_air              14576 non-null  float64
#  43  primary_cleaner.state.floatbank8_b_level            14579 non-null  float64
#  44  primary_cleaner.state.floatbank8_c_air              14579 non-null  float64
#  45  primary_cleaner.state.floatbank8_c_level            14579 non-null  float64
#  46  primary_cleaner.state.floatbank8_d_air              14578 non-null  float64
#  47  primary_cleaner.state.floatbank8_d_level            14579 non-null  float64
#  48  primary_cleaner.output.concentrate_au               14579 non-null  float64
#  49  primary_cleaner.output.concentrate_ag               14579 non-null  float64
#  50  primary_cleaner.output.concentrate_pb               14491 non-null  float64
#  51  primary_cleaner.output.concentrate_sol              14314 non-null  float64
#  52  primary_cleaner.output.tail_au                      14579 non-null  float64
#  53  primary_cleaner.output.tail_ag                      14575 non-null  float64
#  54  primary_cleaner.output.tail_pb                      14573 non-null  float64
#  55  primary_cleaner.output.tail_sol                     14534 non-null  float64
#  56  secondary_cleaner.state.floatbank2_a_air            14485 non-null  float64
#  57  secondary_cleaner.state.floatbank2_a_level          14579 non-null  float64
#  58  secondary_cleaner.state.floatbank2_b_air            14557 non-null  float64
#  59  secondary_cleaner.state.floatbank2_b_level          14579 non-null  float64
#  60  secondary_cleaner.state.floatbank3_a_air            14567 non-null  float64
#  61  secondary_cleaner.state.floatbank3_a_level          14579 non-null  float64
#  62  secondary_cleaner.state.floatbank3_b_air            14579 non-null  float64
#  63  secondary_cleaner.state.floatbank3_b_level          14579 non-null  float64
#  64  secondary_cleaner.state.floatbank4_a_air            14574 non-null  float64
#  65  secondary_cleaner.state.floatbank4_a_level          14579 non-null  float64
#  66  secondary_cleaner.state.floatbank4_b_air            14579 non-null  float64
#  67  secondary_cleaner.state.floatbank4_b_level          14579 non-null  float64
#  68  secondary_cleaner.state.floatbank5_a_air            14579 non-null  float64
#  69  secondary_cleaner.state.floatbank5_a_level          14579 non-null  float64
#  70  secondary_cleaner.state.floatbank5_b_air            14579 non-null  float64
#  71  secondary_cleaner.state.floatbank5_b_level          14579 non-null  float64
#  72  secondary_cleaner.state.floatbank6_a_air            14578 non-null  float64
#  73  secondary_cleaner.state.floatbank6_a_level          14579 non-null  float64
#  74  secondary_cleaner.output.tail_au                    14579 non-null  float64
#  75  secondary_cleaner.output.tail_ag                    14578 non-null  float64
#  76  secondary_cleaner.output.tail_pb                    14575 non-null  float64
#  77  secondary_cleaner.output.tail_sol                   13659 non-null  float64
#  78  final.output.concentrate_au                         14579 non-null  float64
#  79  final.output.concentrate_ag                         14578 non-null  float64
#  80  final.output.concentrate_pb                         14578 non-null  float64
#  81  final.output.concentrate_sol                        14387 non-null  float64
#  82  final.output.recovery                               14579 non-null  float64
#  83  final.output.tail_au                                14579 non-null  float64
#  84  final.output.tail_ag                                14578 non-null  float64
#  85  final.output.tail_pb                                14504 non-null  float64
#  86  final.output.tail_sol                               14574 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 9.7+ MB

# %% [markdown]
# В некоторых столбцах присутствуют пропуски. Т.к. данные представляют собой отсортированную по времени таблицу с часовыми интервалами, можно использовать заполнение пропусков предыдущим валидным значением. Пропусков в целевых параметрах нет.

# %%
train_df.describe()
# Out:
#        rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# count           14579.000000           14579.000000           14507.000000
# mean                8.352941               8.877460               3.604221
# std                 1.934376               1.922536               1.056063
# min                 0.010000               0.010000               0.010000
# 25%                 6.932996               7.341922               2.880490
# 50%                 8.225284               8.715859               3.532399
# 75%                 9.832210              10.255843               4.257282
# max                13.731330              14.596026               7.052325
#
#        rougher.input.feed_sol  rougher.input.feed_rate  \
# count            14502.000000             14572.000000
# mean                36.561420               474.332784
# std                  5.209823               108.503552
# min                  0.010000                 0.002986
# 25%                 34.093951               411.048483
# 50%                 37.097511               498.187968
# 75%                 39.899799               549.586552
# max                 53.475325               717.508837
#
#        rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# count             14478.000000                       14548.000000
# mean                 58.922712                          12.427399
# std                  22.407410                           3.428939
# min                   0.049194                           0.001083
# 25%                  47.278490                          10.002832
# 50%                  54.361187                          12.003320
# 75%                  64.464926                          14.929903
# max                 484.967466                          36.118275
#
#        rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  \
# count                        14572.000000                     14579.000000
# mean                             5.994854                      1104.208278
# std                              1.152873                       162.235606
# min                              0.000568                        -0.042069
# 25%                              5.304167                       999.644856
# 50%                              6.003053                      1000.982624
# 75%                              6.796632                      1292.663971
# max                              9.703448                      1512.299531
#
#        rougher.state.floatbank10_a_level  ...  \
# count                       14579.000000  ...
# mean                         -379.367166  ...
# std                            94.652311  ...
# min                          -657.949759  ...
# 25%                          -499.861797  ...
# 50%                          -300.314199  ...
# 75%                          -299.989315  ...
# max                          -273.776101  ...
#
#        secondary_cleaner.output.tail_sol  final.output.concentrate_au  \
# count                       13659.000000                 14579.000000
# mean                            7.111347                    43.979499
# std                             3.909951                     5.471437
# min                             0.000000                     0.000000
# 25%                             3.784897                    43.345906
# 50%                             7.629968                    44.975014
# 75%                            10.367050                    46.275153
# max                            26.000772                    52.756638
#
#        final.output.concentrate_ag  final.output.concentrate_pb  \
# count                 14578.000000                 14578.000000
# mean                      5.192145                     9.923809
# std                       1.388014                     1.706976
# min                       0.000000                     0.000000
# 25%                       4.283347                     9.103183
# 50%                       5.118647                    10.046455
# 75%                       5.925380                    10.981203
# max                      16.001945                    16.705297
#
#        final.output.concentrate_sol  final.output.recovery  \
# count                  14387.000000           14579.000000
# mean                       9.566676              66.759066
# std                        2.805654              10.619709
# min                        0.000000               0.000000
# 25%                        7.860030              63.114596
# 50%                        9.301970              67.962788
# 75%                       11.001573              72.598187
# max                       19.423912             100.000000
#
#        final.output.tail_au  final.output.tail_ag  final.output.tail_pb  \
# count          14579.000000          14578.000000          14504.000000
# mean               3.087939              9.731972              2.719985
# std                0.915187              2.358143              0.958929
# min                0.000000              0.000000              0.000000
# 25%                2.505287              8.088928              2.036512
# 50%                3.029238              9.818512              2.774847
# 75%                3.614098             11.169187              3.353845
# max                8.245022             19.552149              5.804178
#
#        final.output.tail_sol
# count           14574.000000
# mean               10.612745
# std                 2.871075
# min                 0.000000
# 25%                 9.013412
# 50%                10.670515
# 75%                12.130827
# max                22.317730
#
# [8 rows x 86 columns]

# %% [markdown]
# На первый взгляд аномальных значений в данных нет. Заметно, что уровень во флотаторе принимает отрицательные значения, но, возможно, это связано с измерениеум уровня от верхней границы. Этот вопрос хотелось бы уточнить.

# %%
train_df.corr()
# Out:
#                          rougher.input.feed_au  rougher.input.feed_ag  \
# rougher.input.feed_au                 1.000000               0.840868
# rougher.input.feed_ag                 0.840868               1.000000
# rougher.input.feed_pb                 0.716167               0.527306
# rougher.input.feed_sol                0.121892               0.142085
# rougher.input.feed_rate              -0.175310              -0.112570
# ...                                        ...                    ...
# final.output.recovery                 0.320317               0.309866
# final.output.tail_au                  0.615277               0.467331
# final.output.tail_ag                  0.586762               0.777815
# final.output.tail_pb                  0.499652               0.281709
# final.output.tail_sol                -0.038867              -0.013880
#
#                          rougher.input.feed_pb  rougher.input.feed_sol  \
# rougher.input.feed_au                 0.716167                0.121892
# rougher.input.feed_ag                 0.527306                0.142085
# rougher.input.feed_pb                 1.000000                0.107954
# rougher.input.feed_sol                0.107954                1.000000
# rougher.input.feed_rate              -0.134044                0.620453
# ...                                        ...                     ...
# final.output.recovery                 0.176102                0.258040
# final.output.tail_au                  0.477194               -0.099408
# final.output.tail_ag                  0.407188                0.039348
# final.output.tail_pb                  0.772588               -0.000239
# final.output.tail_sol                -0.156774                0.408207
#
#                          rougher.input.feed_rate  rougher.input.feed_size  \
# rougher.input.feed_au                  -0.175310                -0.132365
# rougher.input.feed_ag                  -0.112570                -0.093059
# rougher.input.feed_pb                  -0.134044                -0.056675
# rougher.input.feed_sol                  0.620453                 0.144052
# rougher.input.feed_rate                 1.000000                 0.066184
# ...                                          ...                      ...
# final.output.recovery                   0.170899                 0.031674
# final.output.tail_au                   -0.283575                -0.159918
# final.output.tail_ag                   -0.030008                -0.048009
# final.output.tail_pb                   -0.239030                -0.097079
# final.output.tail_sol                   0.510010                -0.041124
#
#                          rougher.input.floatbank10_sulfate  \
# rougher.input.feed_au                             0.260829
# rougher.input.feed_ag                             0.070859
# rougher.input.feed_pb                             0.268031
# rougher.input.feed_sol                            0.313654
# rougher.input.feed_rate                           0.257446
# ...                                                    ...
# final.output.recovery                             0.081345
# final.output.tail_au                              0.189767
# final.output.tail_ag                             -0.070658
# final.output.tail_pb                              0.369532
# final.output.tail_sol                             0.201255
#
#                          rougher.input.floatbank10_xanthate  \
# rougher.input.feed_au                              0.211673
# rougher.input.feed_ag                              0.241755
# rougher.input.feed_pb                              0.066555
# rougher.input.feed_sol                             0.395656
# rougher.input.feed_rate                            0.607988
# ...                                                     ...
# final.output.recovery                              0.330164
# final.output.tail_au                              -0.086376
# final.output.tail_ag                               0.290650
# final.output.tail_pb                              -0.156356
# final.output.tail_sol                              0.339642
#
#                          rougher.state.floatbank10_a_air  \
# rougher.input.feed_au                           0.193020
# rougher.input.feed_ag                           0.316638
# rougher.input.feed_pb                           0.278095
# rougher.input.feed_sol                          0.165927
# rougher.input.feed_rate                        -0.000721
# ...                                                  ...
# final.output.recovery                           0.186673
# final.output.tail_au                           -0.017909
# final.output.tail_ag                            0.278435
# final.output.tail_pb                            0.115103
# final.output.tail_sol                          -0.096554
#
#                          rougher.state.floatbank10_a_level  ...  \
# rougher.input.feed_au                            -0.052107  ...
# rougher.input.feed_ag                            -0.074911  ...
# rougher.input.feed_pb                             0.262529  ...
# rougher.input.feed_sol                            0.310125  ...
# rougher.input.feed_rate                           0.128412  ...
# ...                                                    ...  ...
# final.output.recovery                             0.064613  ...
# final.output.tail_au                             -0.115082  ...
# final.output.tail_ag                             -0.068033  ...
# final.output.tail_pb                              0.261150  ...
# final.output.tail_sol                            -0.153207  ...
#
#                          secondary_cleaner.output.tail_sol  \
# rougher.input.feed_au                             0.222046
# rougher.input.feed_ag                             0.246394
# rougher.input.feed_pb                            -0.033530
# rougher.input.feed_sol                           -0.103825
# rougher.input.feed_rate                          -0.020944
# ...                                                    ...
# final.output.recovery                            -0.029615
# final.output.tail_au                              0.244910
# final.output.tail_ag                              0.205762
# final.output.tail_pb                             -0.027103
# final.output.tail_sol                             0.297630
#
#                          final.output.concentrate_au  \
# rougher.input.feed_au                       0.047851
# rougher.input.feed_ag                       0.039050
# rougher.input.feed_pb                       0.016867
# rougher.input.feed_sol                      0.224758
# rougher.input.feed_rate                     0.165220
# ...                                              ...
# final.output.recovery                       0.340427
# final.output.tail_au                       -0.023502
# final.output.tail_ag                        0.101555
# final.output.tail_pb                        0.083138
# final.output.tail_sol                       0.162286
#
#                          final.output.concentrate_ag  \
# rougher.input.feed_au                       0.300447
# rougher.input.feed_ag                       0.439228
# rougher.input.feed_pb                       0.088197
# rougher.input.feed_sol                     -0.029213
# rougher.input.feed_rate                    -0.158517
# ...                                              ...
# final.output.recovery                       0.220187
# final.output.tail_au                        0.184964
# final.output.tail_ag                        0.331187
# final.output.tail_pb                       -0.044452
# final.output.tail_sol                       0.016868
#
#                          final.output.concentrate_pb  \
# rougher.input.feed_au                      -0.051808
# rougher.input.feed_ag                      -0.173866
# rougher.input.feed_pb                       0.287227
# rougher.input.feed_sol                      0.123029
# rougher.input.feed_rate                     0.064433
# ...                                              ...
# final.output.recovery                       0.199200
# final.output.tail_au                       -0.025301
# final.output.tail_ag                       -0.107639
# final.output.tail_pb                        0.215637
# final.output.tail_sol                       0.126428
#
#                          final.output.concentrate_sol  final.output.recovery  \
# rougher.input.feed_au                        0.445847               0.320317
# rougher.input.feed_ag                        0.450498               0.309866
# rougher.input.feed_pb                        0.191184               0.176102
# rougher.input.feed_sol                       0.035540               0.258040
# rougher.input.feed_rate                     -0.131562               0.170899
# ...                                               ...                    ...
# final.output.recovery                        0.312832               1.000000
# final.output.tail_au                         0.219525              -0.391831
# final.output.tail_ag                         0.272380               0.136024
# final.output.tail_pb                         0.213113              -0.130100
# final.output.tail_sol                       -0.037623              -0.021931
#
#                          final.output.tail_au  final.output.tail_ag  \
# rougher.input.feed_au                0.615277              0.586762
# rougher.input.feed_ag                0.467331              0.777815
# rougher.input.feed_pb                0.477194              0.407188
# rougher.input.feed_sol              -0.099408              0.039348
# rougher.input.feed_rate             -0.283575             -0.030008
# ...                                       ...                   ...
# final.output.recovery               -0.391831              0.136024
# final.output.tail_au                 1.000000              0.439097
# final.output.tail_ag                 0.439097              1.000000
# final.output.tail_pb                 0.620136              0.311269
# final.output.tail_sol                0.045037              0.142184
#
#                          final.output.tail_pb  final.output.tail_sol
# rougher.input.feed_au                0.499652              -0.038867
# rougher.input.feed_ag                0.281709              -0.013880
# rougher.input.feed_pb                0.772588              -0.156774
# rougher.input.feed_sol              -0.000239               0.408207
# rougher.input.feed_rate             -0.239030               0.510010
# ...                                       ...                    ...
# final.output.recovery               -0.130100              -0.021931
# final.output.tail_au                 0.620136               0.045037
# final.output.tail_ag                 0.311269               0.142184
# final.output.tail_pb                 1.000000              -0.142567
# final.output.tail_sol               -0.142567               1.000000
#
# [86 rows x 86 columns]

# %%
train_df.corr()[(train_df.corr()[train_df.corr().columns].abs() > 0.7)]
# Out:
#                          rougher.input.feed_au  rougher.input.feed_ag  \
# rougher.input.feed_au                 1.000000               0.840868
# rougher.input.feed_ag                 0.840868               1.000000
# rougher.input.feed_pb                 0.716167                    NaN
# rougher.input.feed_sol                     NaN                    NaN
# rougher.input.feed_rate                    NaN                    NaN
# ...                                        ...                    ...
# final.output.recovery                      NaN                    NaN
# final.output.tail_au                       NaN                    NaN
# final.output.tail_ag                       NaN               0.777815
# final.output.tail_pb                       NaN                    NaN
# final.output.tail_sol                      NaN                    NaN
#
#                          rougher.input.feed_pb  rougher.input.feed_sol  \
# rougher.input.feed_au                 0.716167                     NaN
# rougher.input.feed_ag                      NaN                     NaN
# rougher.input.feed_pb                 1.000000                     NaN
# rougher.input.feed_sol                     NaN                     1.0
# rougher.input.feed_rate                    NaN                     NaN
# ...                                        ...                     ...
# final.output.recovery                      NaN                     NaN
# final.output.tail_au                       NaN                     NaN
# final.output.tail_ag                       NaN                     NaN
# final.output.tail_pb                  0.772588                     NaN
# final.output.tail_sol                      NaN                     NaN
#
#                          rougher.input.feed_rate  rougher.input.feed_size  \
# rougher.input.feed_au                        NaN                      NaN
# rougher.input.feed_ag                        NaN                      NaN
# rougher.input.feed_pb                        NaN                      NaN
# rougher.input.feed_sol                       NaN                      NaN
# rougher.input.feed_rate                      1.0                      NaN
# ...                                          ...                      ...
# final.output.recovery                        NaN                      NaN
# final.output.tail_au                         NaN                      NaN
# final.output.tail_ag                         NaN                      NaN
# final.output.tail_pb                         NaN                      NaN
# final.output.tail_sol                        NaN                      NaN
#
#                          rougher.input.floatbank10_sulfate  \
# rougher.input.feed_au                                  NaN
# rougher.input.feed_ag                                  NaN
# rougher.input.feed_pb                                  NaN
# rougher.input.feed_sol                                 NaN
# rougher.input.feed_rate                                NaN
# ...                                                    ...
# final.output.recovery                                  NaN
# final.output.tail_au                                   NaN
# final.output.tail_ag                                   NaN
# final.output.tail_pb                                   NaN
# final.output.tail_sol                                  NaN
#
#                          rougher.input.floatbank10_xanthate  \
# rougher.input.feed_au                                   NaN
# rougher.input.feed_ag                                   NaN
# rougher.input.feed_pb                                   NaN
# rougher.input.feed_sol                                  NaN
# rougher.input.feed_rate                                 NaN
# ...                                                     ...
# final.output.recovery                                   NaN
# final.output.tail_au                                    NaN
# final.output.tail_ag                                    NaN
# final.output.tail_pb                                    NaN
# final.output.tail_sol                                   NaN
#
#                          rougher.state.floatbank10_a_air  \
# rougher.input.feed_au                                NaN
# rougher.input.feed_ag                                NaN
# rougher.input.feed_pb                                NaN
# rougher.input.feed_sol                               NaN
# rougher.input.feed_rate                              NaN
# ...                                                  ...
# final.output.recovery                                NaN
# final.output.tail_au                                 NaN
# final.output.tail_ag                                 NaN
# final.output.tail_pb                                 NaN
# final.output.tail_sol                                NaN
#
#                          rougher.state.floatbank10_a_level  ...  \
# rougher.input.feed_au                                  NaN  ...
# rougher.input.feed_ag                                  NaN  ...
# rougher.input.feed_pb                                  NaN  ...
# rougher.input.feed_sol                                 NaN  ...
# rougher.input.feed_rate                                NaN  ...
# ...                                                    ...  ...
# final.output.recovery                                  NaN  ...
# final.output.tail_au                                   NaN  ...
# final.output.tail_ag                                   NaN  ...
# final.output.tail_pb                                   NaN  ...
# final.output.tail_sol                                  NaN  ...
#
#                          secondary_cleaner.output.tail_sol  \
# rougher.input.feed_au                                  NaN
# rougher.input.feed_ag                                  NaN
# rougher.input.feed_pb                                  NaN
# rougher.input.feed_sol                                 NaN
# rougher.input.feed_rate                                NaN
# ...                                                    ...
# final.output.recovery                                  NaN
# final.output.tail_au                                   NaN
# final.output.tail_ag                                   NaN
# final.output.tail_pb                                   NaN
# final.output.tail_sol                                  NaN
#
#                          final.output.concentrate_au  \
# rougher.input.feed_au                            NaN
# rougher.input.feed_ag                            NaN
# rougher.input.feed_pb                            NaN
# rougher.input.feed_sol                           NaN
# rougher.input.feed_rate                          NaN
# ...                                              ...
# final.output.recovery                            NaN
# final.output.tail_au                             NaN
# final.output.tail_ag                             NaN
# final.output.tail_pb                             NaN
# final.output.tail_sol                            NaN
#
#                          final.output.concentrate_ag  \
# rougher.input.feed_au                            NaN
# rougher.input.feed_ag                            NaN
# rougher.input.feed_pb                            NaN
# rougher.input.feed_sol                           NaN
# rougher.input.feed_rate                          NaN
# ...                                              ...
# final.output.recovery                            NaN
# final.output.tail_au                             NaN
# final.output.tail_ag                             NaN
# final.output.tail_pb                             NaN
# final.output.tail_sol                            NaN
#
#                          final.output.concentrate_pb  \
# rougher.input.feed_au                            NaN
# rougher.input.feed_ag                            NaN
# rougher.input.feed_pb                            NaN
# rougher.input.feed_sol                           NaN
# rougher.input.feed_rate                          NaN
# ...                                              ...
# final.output.recovery                            NaN
# final.output.tail_au                             NaN
# final.output.tail_ag                             NaN
# final.output.tail_pb                             NaN
# final.output.tail_sol                            NaN
#
#                          final.output.concentrate_sol  final.output.recovery  \
# rougher.input.feed_au                             NaN                    NaN
# rougher.input.feed_ag                             NaN                    NaN
# rougher.input.feed_pb                             NaN                    NaN
# rougher.input.feed_sol                            NaN                    NaN
# rougher.input.feed_rate                           NaN                    NaN
# ...                                               ...                    ...
# final.output.recovery                             NaN                    1.0
# final.output.tail_au                              NaN                    NaN
# final.output.tail_ag                              NaN                    NaN
# final.output.tail_pb                              NaN                    NaN
# final.output.tail_sol                             NaN                    NaN
#
#                          final.output.tail_au  final.output.tail_ag  \
# rougher.input.feed_au                     NaN                   NaN
# rougher.input.feed_ag                     NaN              0.777815
# rougher.input.feed_pb                     NaN                   NaN
# rougher.input.feed_sol                    NaN                   NaN
# rougher.input.feed_rate                   NaN                   NaN
# ...                                       ...                   ...
# final.output.recovery                     NaN                   NaN
# final.output.tail_au                      1.0                   NaN
# final.output.tail_ag                      NaN              1.000000
# final.output.tail_pb                      NaN                   NaN
# final.output.tail_sol                     NaN                   NaN
#
#                          final.output.tail_pb  final.output.tail_sol
# rougher.input.feed_au                     NaN                    NaN
# rougher.input.feed_ag                     NaN                    NaN
# rougher.input.feed_pb                0.772588                    NaN
# rougher.input.feed_sol                    NaN                    NaN
# rougher.input.feed_rate                   NaN                    NaN
# ...                                       ...                    ...
# final.output.recovery                     NaN                    NaN
# final.output.tail_au                      NaN                    NaN
# final.output.tail_ag                      NaN                    NaN
# final.output.tail_pb                 1.000000                    NaN
# final.output.tail_sol                     NaN                    1.0
#
# [86 rows x 86 columns]

# %%
train_df.corr()[train_df.corr()['final.output.recovery'].abs() > 0.7]
# Out:
#                        rougher.input.feed_au  rougher.input.feed_ag  \
# final.output.recovery               0.320317               0.309866
#
#                        rougher.input.feed_pb  rougher.input.feed_sol  \
# final.output.recovery               0.176102                 0.25804
#
#                        rougher.input.feed_rate  rougher.input.feed_size  \
# final.output.recovery                 0.170899                 0.031674
#
#                        rougher.input.floatbank10_sulfate  \
# final.output.recovery                           0.081345
#
#                        rougher.input.floatbank10_xanthate  \
# final.output.recovery                            0.330164
#
#                        rougher.state.floatbank10_a_air  \
# final.output.recovery                         0.186673
#
#                        rougher.state.floatbank10_a_level  ...  \
# final.output.recovery                           0.064613  ...
#
#                        secondary_cleaner.output.tail_sol  \
# final.output.recovery                          -0.029615
#
#                        final.output.concentrate_au  \
# final.output.recovery                     0.340427
#
#                        final.output.concentrate_ag  \
# final.output.recovery                     0.220187
#
#                        final.output.concentrate_pb  \
# final.output.recovery                       0.1992
#
#                        final.output.concentrate_sol  final.output.recovery  \
# final.output.recovery                      0.312832                    1.0
#
#                        final.output.tail_au  final.output.tail_ag  \
# final.output.recovery             -0.391831              0.136024
#
#                        final.output.tail_pb  final.output.tail_sol
# final.output.recovery               -0.1301              -0.021931
#
# [1 rows x 86 columns]

# %%
train_df.corr()[train_df.corr()['rougher.output.recovery'].abs() > 0.7]['rougher.output.recovery']
# Out:
# rougher.output.concentrate_ag    0.708299
# rougher.output.recovery          1.000000
# Name: rougher.output.recovery, dtype: float64

# %% [markdown]
# Сильная корреляция между эффективностью обогащения финального концентрата и остальными признаками отсутствует. Есть прямая корреляция между эффективностью обогащения чернового концентрата и содержанием в нем серебра. Заметно наличие корреляции между концентрациями золота, серебра и свинца в сырье, а также в между серебром и свинцом на входе и в хвостах.
#
# Сравним значения `rougher.output.recovery` из датасета и рассчетом по формуле
#
# <img src= "https://pictures.s3.yandex.net/resources/Recovery_1576238822.jpg" alt="Recovery" style="width: 600px;"/>
#
# где:
#
# C — доля золота в концентрате после флотации, т.е. `rougher.output.concentrate_au`;
#
# F — доля золота в сырье до флотации, т.е. `rougher.input.feed_au`;
#
# T — доля золота в отвальных хвостах после флотации, т.е. `rougher.output.tail_au`.

# %%
recovery_calc = ((train_df['rougher.output.concentrate_au'] * 
                  (train_df['rougher.input.feed_au'] - train_df['rougher.output.tail_au'])) / 
                 (train_df['rougher.input.feed_au'] * 
                  (train_df['rougher.output.concentrate_au'] - train_df['rougher.output.tail_au'])) * 100)

mean_absolute_error(train_df['rougher.output.recovery'], recovery_calc)
# Out:
# 9.83758577644259e-15

# %% [markdown]
# Сравнение расчетных значений и значений из датасета показывает очень маленькое отклонение, что говорит о точности результатов расчетной формулы.

# %% [markdown]
# ### Вывод
# Исходные данные содержат достаточно большое количество признаков (86), при этом в тестовой выборке отсутствуют признаки (34 столбца), которые неизвестны в процессе обогащения, соответственно, из тренировочного датасета их необходимо будет исключить. Также в тренировочной выборке есть пропуски, их можно заменить последним валидным значением, т.к. соседние по времени параметры похожи. Обработку пропущенных значений внесем в пайплайн. Сильная корреляция между эффективностью обогащения финального концентрата и остальными признаками отсутствует. Есть прямая корреляция между эффективностью обогащения чернового концентрата и содержанием в нем серебра. Заметно наличие корреляции между концентрациями золота, серебра и свинца в сырье, а также между серебром и свинцом на входе и в хвостах. Значения эффективности обогащения соответствуют расчетным.

# %% [markdown]
# ## 2. Исследовательский анализ.
# На этом этапе необходимо:
#
#     1. исследовать изменения концентрации металлов в сырье и концентратах на разных стадиях;
#     2. исследовать суммарную концентрацию металлов на разных стадиях;
#     3. проверить, чтобы распределения размеров гранул в тренировочной и тестовой выборках были похожи. Это необходимо для правильности работы модели.

# %% [markdown]
# ### 2.1. Изменение концентрации металлов.

# %%
plt.figure(figsize=(12,4))
sns.kdeplot(data=train_df[['rougher.input.feed_au', 'rougher.output.concentrate_au', 
                       'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au']], fill=True)
plt.title('Концентрация золота на разных стадиях процесса')
plt.legend(['После второго этапа очистки', 'После первого этапа очистки', 'После флотатора', 'В сырье'])
plt.xlabel('Концентрация золота')
plt.show()

# %% [markdown]
# Концентрация золота в смеси возрастает на каждом этапе обогащения. Распределения имеют нормальную форму

# %%
plt.figure(figsize=(12,4))
sns.kdeplot(data=train_df[['rougher.input.feed_ag', 'rougher.output.concentrate_ag', 
                       'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag']], fill=True)
plt.title('Концентрация серебра на разных стадиях процесса')
plt.legend(['После второго этапа очистки', 'После первого этапа очистки', 'После флотатора', 'В сырье'])
plt.xlabel('Концентрация серебра')
plt.show()

# %% [markdown]
# Концентрация серебра в смеси повышается после флотатора (вот возможная причина корреляции между эффективностью обогащения чернового концентрата и содержанием серебра) и снижается в среднем до 5 в конце обогащения. Распределения имеют хвосты, особенно на начальных стадиях. Утолщение в районе нуля показывает, что бывает сырье без содержания серебра.

# %%
plt.figure(figsize=(12,4))
sns.kdeplot(data=train_df[['rougher.input.feed_pb', 'rougher.output.concentrate_pb', 
                       'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb']], fill=True)
plt.title('Концентрация свинца на разных стадиях процесса')
plt.legend(['После второго этапа очистки', 'После первого этапа очистки', 'После флотатора', 'В сырье'])
plt.xlabel('Концентрация свинца')
plt.show()

# %% [markdown]
# Содержание свинца в смеси растет в процессе обогащения.

# %% [markdown]
# #### Вывод
# Содержание золота и свинца возростает в процессе обогащения в среднем до 45 и 10 соответственно. Концентрация серебра растет в процессе флотации и снижается на следующих стадиях в среднем до 5. У распределений всех металлов по стадиям присутствует утолщение в районе нуля.

# %% [markdown]
# ### 2.2. Суммарная концентрация металлов по стадиям.

# %%
# Концентрация металлов в начале процесса
start = train_df['rougher.input.feed_au'] + train_df['rougher.input.feed_ag'] + train_df['rougher.input.feed_pb']

# Концентрация металлов после флотатора
rougher = train_df['rougher.output.concentrate_au'] + train_df['rougher.output.concentrate_ag'] \
                         + train_df['rougher.output.concentrate_pb']

# Концентрация металлов после первой стадии очистки
primary_cleaner = train_df['primary_cleaner.output.concentrate_au'] + train_df['primary_cleaner.output.concentrate_ag'] \
                         + train_df['primary_cleaner.output.concentrate_pb']

# Концентрация металлов после второй стадии очистки
final = train_df['final.output.concentrate_au'] + train_df['final.output.concentrate_ag'] \
                         + train_df['final.output.concentrate_pb']

# %%
plt.figure(figsize=(12,4))
sns.kdeplot(data=pd.concat([start, rougher, primary_cleaner, final], axis=1), fill=True)
plt.legend(['После второго этапа очистки', 'После первого этапа очистки', 'После флотатора', 'В сырье'])
plt.title('Суммарная концентрация металлов на разных стадиях процесса')
plt.xlabel('Концентрация металлов')
plt.show()

# %% [markdown]
# Распределения суммарных концентраций на разных стадиях процесса имеют утолщение в районе нуля. Это похоже на аномальные значения. Их следует удалить из обучающей выборки. Посмотрим сколько их в датасете

# %%
((start == 0) | (rougher == 0) | (primary_cleaner == 0) | (final == 0)).sum()
# Out:
# 591

# %% [markdown]
# Удалим эти строки

# %%
train_df = train_df[~((start == 0) | (rougher == 0) | (primary_cleaner == 0) | (final == 0))]

# %% [markdown]
# #### Вывод
# Концентрация металлов в процессе очистки возрастает до 60, что соответствует оценкам при исследовании изменения концентрации металлов по стадиям. Дисперсия распределений уменьшается. Присутствует утолщение плотности вероятности распределений суммарных концентраций на разных стадиях процесса. Это похоже на аномальные значения. Исключили эти строки из обучающей выборки

# %% [markdown]
# ### 2.3. Распределение размера гранул.

# %%
plt.figure(figsize=(12,4))
sns.kdeplot(data=train_df['rougher.input.feed_size'], fill=True)
sns.kdeplot(data=test_df['rougher.input.feed_size'], fill=True)
plt.title('Распределение размера гранул по выборкам')
plt.legend(['Тренировочная выборка', 'Тестовая выборка'])
plt.xlabel('Размер гранул сырья')
plt.show()

# %% [markdown]
# #### Вывод
# Распределения гранул в тренировочной и тестовой выборках имеют похожую форму. Таким образом, данный параметр не будет искажать оценки модели.

# %% [markdown]
# ### Вывод
# Исследовательский анализ показал возрастание концентрации металлов в смеси в процессе обогащения и снижение дисперсии распределений концентрации. Концентрация золота возрастает на всех этапах процесса. Концентрация серебра возрастает на этапе флотации, а дельше снижается. Концентрация свинца растет до второй стадии очистки. На второй стадии очистки концентрация свинца почти не меняется, но снижается дисперсия. Распределения размера гранул в тренировочной и тестовой выборках очень похожи, поэтому данный параметр не будет искажать результаты оценки модели.

# %% [markdown]
# ## 3. Построение и проверка моделей.
# В процессе предобработки необходимо удалить столбцы, отсутствующие в тестовой выборке, из тренировочной. Заполнение пропусков данных предыдущим валидным значением лучше добавить в пайплайн вместе с стандартизацией параметров и кросс-валидацией.
# ### 3.1. Метрика sMAPE.
# Оценка модели происходит на основании метрики sMAPE - симметричное среднее абсолютное процентное отклонение. Для использования её в оптимизации моделей необходимо написать функцию в соотвествии с формулой:
#
# <img src= "https://pictures.s3.yandex.net/resources/smape_1576238825.jpg" alt="sMAPE" style="width: 600px;"/>

# %%
# Функция для расчета sMAPE
def smape(target, prediction):
    smape = np.sum(np.mean(np.abs(target - prediction) / 
                           ((np.abs(target) + np.abs(prediction)) / 2))) * 100
    return smape

# Превращаем функцию в метрику
smape_score = make_scorer(smape, greater_is_better=False)

# %% [markdown]
# ### 3.2. Подготовка выборок.
# Подготовим тренировочные и тестовые выборки для двух целевых параметров

# %%
# Сделаем столбец с датой индексом
train_df.set_index('date', drop=True, inplace=True)
test_df.set_index('date', drop=True, inplace=True)

# Теперь сделаем тренировочную выборку с параметрами, доступными на этапе флотации
rougher_train_X = train_df[
    ['rougher.input.feed_au', 'rougher.input.feed_ag',
       'rougher.input.feed_pb', 'rougher.input.feed_sol',
       'rougher.input.feed_rate', 'rougher.input.feed_size',
       'rougher.input.floatbank10_sulfate',
       'rougher.input.floatbank10_xanthate', 'rougher.state.floatbank10_a_air',
       'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
       'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
       'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
       'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
       'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
       'rougher.state.floatbank10_f_level',
       'rougher.input.floatbank11_sulfate',
       'rougher.input.floatbank11_xanthate',]
]

# Тренировочная выборка с целевым значением на флотации
rougher_train_y = train_df['rougher.output.recovery']

# Тренировочная выборка с параметрами для финального значения эффективности
final_train_X = train_df.drop(['final.output.recovery', *missing_columns], axis=1)

# Тренировочная выборка с финальным значением эффективности
final_train_y = train_df['final.output.recovery']

# %%
# Сделаем столбец с датой индексом для полной выборки
full_df.set_index('date', drop=True, inplace=True)

# Тестовая выборка с параметрами флотации
rougher_test_X = test_df[
    ['rougher.input.feed_au', 'rougher.input.feed_ag',
       'rougher.input.feed_pb', 'rougher.input.feed_sol',
       'rougher.input.feed_rate', 'rougher.input.feed_size',
       'rougher.input.floatbank10_sulfate',
       'rougher.input.floatbank10_xanthate', 'rougher.state.floatbank10_a_air',
       'rougher.state.floatbank10_a_level', 'rougher.state.floatbank10_b_air',
       'rougher.state.floatbank10_b_level', 'rougher.state.floatbank10_c_air',
       'rougher.state.floatbank10_c_level', 'rougher.state.floatbank10_d_air',
       'rougher.state.floatbank10_d_level', 'rougher.state.floatbank10_e_air',
       'rougher.state.floatbank10_e_level', 'rougher.state.floatbank10_f_air',
       'rougher.state.floatbank10_f_level',
       'rougher.input.floatbank11_sulfate',
       'rougher.input.floatbank11_xanthate',]
]

# Тестовая выборка с целевым значением на флотации
rougher_test_y = pd.Series(full_df['rougher.output.recovery'], test_df.index)

# Тестовая выборка с параметрами для финального значения эффективности
final_test_X = test_df

# Тестовая выборка с финальным значением эффективности
final_test_y = pd.Series(full_df['final.output.recovery'], test_df.index)

# %% [markdown]
# ### 3.3. Построение конвейеров моделей.
# Для заполнения пропусков в датасете на предыдущее валидное значение внутри пайплайна нужно написать класс заполнителя с методом "ffill".

# %%
# Создаем класс для заполнения пропусков предыдущим вылидным значением
class ForwardFillImputer(TransformerMixin, BaseEstimator):
    def __init__(self, columns=None):
        self.columns = columns
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        if self.columns is None:
            self.columns = X.columns
        
        X = X.copy()
        X[self.columns] = X[self.columns].fillna(method='ffill')
        return X

# %% [markdown]
# #### 3.3.1. Выбор модели для оценки эффективности обогащения чернового концентрата.

# %%
lr_pipe = Pipeline([
    ('imputer1', ForwardFillImputer()),
    ('imputer2', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler()),
    ('regressor', LinearRegression())
])

lr_param_grid = {'regressor__fit_intercept':[True, False]}

grid_lr_rougher = GridSearchCV(lr_pipe, param_grid=lr_param_grid, cv=5, verbose=3, scoring=smape_score)

grid_lr_rougher.fit(rougher_train_X, rougher_train_y)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END ....regressor__fit_intercept=True;, score=-8.186 total time=   0.0s
# [CV 2/5] END ....regressor__fit_intercept=True;, score=-6.023 total time=   0.0s
# [CV 3/5] END ....regressor__fit_intercept=True;, score=-4.693 total time=   0.0s
# [CV 4/5] END ....regressor__fit_intercept=True;, score=-4.495 total time=   0.0s
# [CV 5/5] END ....regressor__fit_intercept=True;, score=-9.164 total time=   0.0s
# [CV 1/5] END .regressor__fit_intercept=False;, score=-198.853 total time=   0.0s
# [CV 2/5] END .regressor__fit_intercept=False;, score=-197.577 total time=   0.0s
# [CV 3/5] END .regressor__fit_intercept=False;, score=-192.739 total time=   0.0s
# [CV 4/5] END .regressor__fit_intercept=False;, score=-186.255 total time=   0.0s
# [CV 5/5] END .regressor__fit_intercept=False;, score=-191.500 total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('imputer1', ForwardFillImputer()),
#                                        ('imputer2',
#                                         SimpleImputer(strategy='median')),
#                                        ('scaler', StandardScaler()),
#                                        ('regressor', LinearRegression())]),
#              param_grid={'regressor__fit_intercept': [True, False]},
#              scoring=make_scorer(smape, greater_is_better=False), verbose=3)

# %%
grid_lr_rougher.best_score_, grid_lr_rougher.best_params_
# Out:
# (-6.512001457867031, {'regressor__fit_intercept': True})

# %%
rfr_pipe = Pipeline([
    ('imputer', ForwardFillImputer()),
    ('regressor', RandomForestRegressor(n_jobs=-1, random_state=12))
])

rfr_param_grid = {'regressor__max_depth': range(5, 16, 5),
                 'regressor__n_estimators': range(200, 301, 50),
                 'regressor__min_samples_leaf': range(35, 46, 5)}

grid_rfr_rougher = GridSearchCV(rfr_pipe, param_grid=rfr_param_grid, cv=3, verbose=3, scoring=smape_score)

grid_rfr_rougher.fit(rougher_train_X, rougher_train_y)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-7.689 total time=   3.2s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-4.980 total time=   2.0s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-6.242 total time=   1.9s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-7.687 total time=   2.5s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-4.992 total time=   2.8s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-6.249 total time=   2.8s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-7.676 total time=   3.2s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-5.001 total time=   2.9s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-6.274 total time=   3.1s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-7.688 total time=   1.7s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-4.969 total time=   1.9s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-6.240 total time=   1.8s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-7.688 total time=   2.3s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-4.992 total time=   2.2s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-6.265 total time=   2.2s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-7.677 total time=   3.2s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-4.991 total time=   2.6s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-6.284 total time=   2.6s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-7.696 total time=   2.0s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-4.933 total time=   1.9s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-6.308 total time=   1.8s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-7.700 total time=   2.2s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-4.959 total time=   2.2s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-6.320 total time=   2.2s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-7.691 total time=   2.7s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-4.963 total time=   2.9s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-6.324 total time=   2.6s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-7.613 total time=   2.7s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-5.106 total time=   2.6s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-6.477 total time=   3.1s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-7.598 total time=   3.6s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-5.101 total time=   3.8s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-6.484 total time=   3.7s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-7.597 total time=   3.9s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-5.092 total time=   4.2s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-6.493 total time=   4.0s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-7.641 total time=   3.0s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-5.071 total time=   2.6s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-6.449 total time=   2.5s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-7.621 total time=   3.4s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-5.081 total time=   3.4s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-6.468 total time=   3.1s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-7.617 total time=   3.9s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-5.070 total time=   4.2s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-6.476 total time=   4.1s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-7.665 total time=   2.5s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-5.020 total time=   2.5s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-6.484 total time=   2.5s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-7.655 total time=   3.2s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-5.037 total time=   3.4s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-6.491 total time=   3.1s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-7.650 total time=   3.8s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-5.041 total time=   3.8s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-6.495 total time=   4.0s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-7.571 total time=   2.8s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-5.087 total time=   2.7s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-6.489 total time=   2.7s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-7.557 total time=   3.5s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-5.076 total time=   3.7s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-6.494 total time=   3.4s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-7.554 total time=   4.2s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-5.070 total time=   4.1s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-6.502 total time=   4.3s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-7.607 total time=   2.7s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-5.047 total time=   2.7s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-6.461 total time=   2.6s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-7.586 total time=   3.4s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-5.060 total time=   3.6s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-6.478 total time=   3.5s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-7.583 total time=   4.2s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-5.053 total time=   4.0s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-6.487 total time=   4.2s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-7.640 total time=   2.8s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-5.009 total time=   2.6s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-6.496 total time=   2.5s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-7.628 total time=   3.3s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-5.027 total time=   3.7s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-6.501 total time=   3.8s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-7.625 total time=   4.0s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-5.030 total time=   4.0s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-6.506 total time=   4.5s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('imputer', ForwardFillImputer()),
#                                        ('regressor',
#                                         RandomForestRegressor(n_jobs=-1,
#                                                               random_state=12))]),
#              param_grid={'regressor__max_depth': range(5, 16, 5),
#                          'regressor__min_samples_leaf': range(35, 46, 5),
#                          'regressor__n_estimators': range(200, 301, 50)},
#              scoring=make_scorer(smape, greater_is_better=False), verbose=3)

# %%
grid_rfr_rougher.best_score_, grid_rfr_rougher.best_params_
# Out:
# (-6.298930827459524,
#  {'regressor__max_depth': 5,
#   'regressor__min_samples_leaf': 40,
#   'regressor__n_estimators': 200})

# %%
knnr_pipe = Pipeline([
    ('imputer', ForwardFillImputer()),
    ('scaler', StandardScaler()),
    ('regressor', KNeighborsRegressor(n_jobs=-1))
])

knnr_param_grid = {'regressor__n_neighbors': range(45, 51, 5),
                 'regressor__weights': ['uniform', 'distance'],
                 'regressor__algorithm': ['ball_tree', 'kd_tree']}

grid_knnr_rougher = GridSearchCV(knnr_pipe, param_grid=knnr_param_grid, cv=3, verbose=3, scoring=smape_score)

grid_knnr_rougher.fit(rougher_train_X, rougher_train_y)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-8.745 total time=   0.2s
# [CV 2/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-5.425 total time=   0.2s
# [CV 3/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-7.744 total time=   0.2s
# [CV 1/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-8.735 total time=   0.2s
# [CV 2/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-5.419 total time=   0.2s
# [CV 3/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-7.734 total time=   0.2s
# [CV 1/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-8.749 total time=   0.2s
# [CV 2/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-5.401 total time=   0.2s
# [CV 3/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-7.753 total time=   0.2s
# [CV 1/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-8.738 total time=   0.2s
# [CV 2/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-5.394 total time=   0.2s
# [CV 3/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-7.741 total time=   0.2s
# [CV 1/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-8.745 total time=   0.2s
# [CV 2/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-5.425 total time=   0.3s
# [CV 3/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-7.744 total time=   0.3s
# [CV 1/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-8.735 total time=   0.3s
# [CV 2/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-5.419 total time=   0.3s
# [CV 3/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-7.734 total time=   0.3s
# [CV 1/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-8.749 total time=   0.3s
# [CV 2/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-5.401 total time=   0.3s
# [CV 3/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-7.753 total time=   0.3s
# [CV 1/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-8.738 total time=   0.3s
# [CV 2/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-5.394 total time=   0.3s
# [CV 3/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-7.741 total time=   0.3s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('imputer', ForwardFillImputer()),
#                                        ('scaler', StandardScaler()),
#                                        ('regressor',
#                                         KNeighborsRegressor(n_jobs=-1))]),
#              param_grid={'regressor__algorithm': ['ball_tree', 'kd_tree'],
#                          'regressor__n_neighbors': range(45, 51, 5),
#                          'regressor__weights': ['uniform', 'distance']},
#              scoring=make_scorer(smape, greater_is_better=False), verbose=3)

# %%
grid_knnr_rougher.best_score_, grid_knnr_rougher.best_params_
# Out:
# (-7.290938390750067,
#  {'regressor__algorithm': 'ball_tree',
#   'regressor__n_neighbors': 50,
#   'regressor__weights': 'distance'})

# %% [markdown]
# Лучшее значение метрики sMAPE показала модель случайного леса. Её и возьмем для оценки эффективности обогащения чернового концентрата на тестовой выборке.

# %% [markdown]
# #### 3.3.2. Выбор модели для оценки эффективности обогащения финального концентрата.

# %%
grid_lr_final = GridSearchCV(lr_pipe, param_grid=lr_param_grid, cv=5, verbose=3, scoring=smape_score)

grid_lr_final.fit(final_train_X, final_train_y)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END ...regressor__fit_intercept=True;, score=-10.543 total time=   0.0s
# [CV 2/5] END ....regressor__fit_intercept=True;, score=-8.296 total time=   0.0s
# [CV 3/5] END ....regressor__fit_intercept=True;, score=-8.782 total time=   0.0s
# [CV 4/5] END ....regressor__fit_intercept=True;, score=-8.807 total time=   0.0s
# [CV 5/5] END ...regressor__fit_intercept=True;, score=-11.213 total time=   0.0s
# [CV 1/5] END .regressor__fit_intercept=False;, score=-192.276 total time=   0.1s
# [CV 2/5] END .regressor__fit_intercept=False;, score=-184.820 total time=   0.0s
# [CV 3/5] END .regressor__fit_intercept=False;, score=-189.768 total time=   0.0s
# [CV 4/5] END .regressor__fit_intercept=False;, score=-183.849 total time=   0.0s
# [CV 5/5] END .regressor__fit_intercept=False;, score=-190.360 total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('imputer1', ForwardFillImputer()),
#                                        ('imputer2',
#                                         SimpleImputer(strategy='median')),
#                                        ('scaler', StandardScaler()),
#                                        ('regressor', LinearRegression())]),
#              param_grid={'regressor__fit_intercept': [True, False]},
#              scoring=make_scorer(smape, greater_is_better=False), verbose=3)

# %%
grid_lr_final.best_score_, grid_lr_final.best_params_
# Out:
# (-9.528133436618777, {'regressor__fit_intercept': True})

# %%
grid_rfr_final = GridSearchCV(rfr_pipe, param_grid=rfr_param_grid, cv=3, verbose=3, scoring=smape_score)

grid_rfr_final.fit(final_train_X, final_train_y)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-8.923 total time=   4.2s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-9.038 total time=   4.4s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-12.553 total time=   4.1s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-8.918 total time=   5.2s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-9.040 total time=   5.6s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-12.520 total time=   5.2s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-8.911 total time=   6.1s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-9.029 total time=   6.5s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-12.500 total time=   6.1s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-8.916 total time=   4.3s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-9.020 total time=   4.3s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-12.466 total time=   4.1s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-8.911 total time=   5.2s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-9.014 total time=   5.5s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-12.439 total time=   5.2s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-8.905 total time=   6.1s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-9.007 total time=   6.6s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-12.422 total time=   6.2s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-8.926 total time=   4.3s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-9.021 total time=   4.2s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-12.344 total time=   4.1s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-8.914 total time=   5.1s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-9.019 total time=   5.4s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-12.326 total time=   5.1s
# [CV 1/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-8.912 total time=   6.4s
# [CV 2/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-9.008 total time=   6.8s
# [CV 3/3] END regressor__max_depth=5, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-12.313 total time=   6.5s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-8.918 total time=   7.0s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-9.012 total time=   6.3s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-12.288 total time=   7.0s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-8.923 total time=   8.7s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-9.005 total time=   9.0s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-12.271 total time=   8.5s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-8.917 total time=  10.3s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-9.018 total time=  10.7s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-12.285 total time=  10.1s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-8.906 total time=   7.2s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-8.997 total time=   6.4s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-12.203 total time=   6.6s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-8.906 total time=   8.3s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-8.978 total time=   7.5s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-12.188 total time=   8.1s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-8.899 total time=   9.8s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-8.994 total time=   8.9s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-12.201 total time=   9.9s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-8.935 total time=   6.3s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-9.022 total time=   6.2s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-12.137 total time=   6.4s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-8.927 total time=   7.9s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-9.006 total time=   7.4s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-12.131 total time=   7.9s
# [CV 1/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-8.927 total time=   9.7s
# [CV 2/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-9.005 total time=   9.1s
# [CV 3/3] END regressor__max_depth=10, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-12.139 total time=   9.3s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-8.923 total time=   7.7s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-9.010 total time=   6.4s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=200;, score=-12.264 total time=   7.4s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-8.925 total time=   8.8s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-9.005 total time=   8.6s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=250;, score=-12.248 total time=   9.1s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-8.919 total time=  11.0s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-9.020 total time=   9.7s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=35, regressor__n_estimators=300;, score=-12.256 total time=  10.6s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-8.914 total time=   7.2s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-8.995 total time=   6.2s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=200;, score=-12.190 total time=   7.1s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-8.910 total time=   8.6s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-8.979 total time=   8.4s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=250;, score=-12.181 total time=   8.5s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-8.902 total time=  10.5s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-8.996 total time=   9.6s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=40, regressor__n_estimators=300;, score=-12.191 total time=  13.3s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-8.945 total time=   7.2s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-9.026 total time=   6.0s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=200;, score=-12.125 total time=   8.3s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-8.936 total time=   9.5s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-9.007 total time=  11.2s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=250;, score=-12.121 total time=  13.1s
# [CV 1/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-8.935 total time=  12.3s
# [CV 2/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-9.007 total time=   9.6s
# [CV 3/3] END regressor__max_depth=15, regressor__min_samples_leaf=45, regressor__n_estimators=300;, score=-12.128 total time=  11.2s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('imputer', ForwardFillImputer()),
#                                        ('regressor',
#                                         RandomForestRegressor(n_jobs=-1,
#                                                               random_state=12))]),
#              param_grid={'regressor__max_depth': range(5, 16, 5),
#                          'regressor__min_samples_leaf': range(35, 46, 5),
#                          'regressor__n_estimators': range(200, 301, 50)},
#              scoring=make_scorer(smape, greater_is_better=False), verbose=3)

# %%
grid_rfr_final.best_score_, grid_rfr_final.best_params_
# Out:
# (-10.021053241050321,
#  {'regressor__max_depth': 10,
#   'regressor__min_samples_leaf': 45,
#   'regressor__n_estimators': 250})

# %%
grid_knnr_final = GridSearchCV(knnr_pipe, param_grid=knnr_param_grid, cv=3, verbose=3, scoring=smape_score)

grid_knnr_final.fit(final_train_X, final_train_y)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV 1/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-9.893 total time=   0.5s
# [CV 2/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-10.005 total time=   0.5s
# [CV 3/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-11.841 total time=   0.5s
# [CV 1/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-9.890 total time=   0.5s
# [CV 2/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-10.026 total time=   0.5s
# [CV 3/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-11.846 total time=   0.5s
# [CV 1/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-9.900 total time=   0.5s
# [CV 2/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-9.990 total time=   0.5s
# [CV 3/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-11.773 total time=   0.5s
# [CV 1/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-9.897 total time=   0.5s
# [CV 2/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-10.005 total time=   0.5s
# [CV 3/3] END regressor__algorithm=ball_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-11.779 total time=   0.5s
# [CV 1/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-9.893 total time=   0.7s
# [CV 2/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-10.005 total time=   0.8s
# [CV 3/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=uniform;, score=-11.841 total time=   0.7s
# [CV 1/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-9.890 total time=   0.9s
# [CV 2/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-10.026 total time=   0.8s
# [CV 3/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=45, regressor__weights=distance;, score=-11.846 total time=   0.8s
# [CV 1/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-9.900 total time=   0.8s
# [CV 2/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-9.990 total time=   0.7s
# [CV 3/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=uniform;, score=-11.773 total time=   0.8s
# [CV 1/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-9.897 total time=   0.8s
# [CV 2/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-10.005 total time=   0.8s
# [CV 3/3] END regressor__algorithm=kd_tree, regressor__n_neighbors=50, regressor__weights=distance;, score=-11.779 total time=   0.8s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('imputer', ForwardFillImputer()),
#                                        ('scaler', StandardScaler()),
#                                        ('regressor',
#                                         KNeighborsRegressor(n_jobs=-1))]),
#              param_grid={'regressor__algorithm': ['ball_tree', 'kd_tree'],
#                          'regressor__n_neighbors': range(45, 51, 5),
#                          'regressor__weights': ['uniform', 'distance']},
#              scoring=make_scorer(smape, greater_is_better=False), verbose=3)

# %%
grid_knnr_final.best_score_, grid_knnr_final.best_params_
# Out:
# (-10.55425159855058,
#  {'regressor__algorithm': 'ball_tree',
#   'regressor__n_neighbors': 50,
#   'regressor__weights': 'uniform'})

# %% [markdown]
# Лучшее значение метрики sMAPE показала модель линейной регрессии. Её и возьмем для оценки эффективности обогащения финального концентрата на тестовой выборке.

# %% [markdown]
# ### 3.3. Проверка моделей.
# Проверим лучшие модели на тестовой выборке и рассчитаем итоговое sMAPE для всего процесса по формуле:
#
# <img src= "https://pictures.s3.yandex.net/resources/_smape_1576239054.jpg" alt="total_sMAPE" style="width: 600px;"/>

# %%
# Оценка эффективности обогащения чернового концентрата
rougher_pred = grid_rfr_rougher.predict(rougher_test_X)
rougher_smape = smape(rougher_test_y, rougher_pred)

# Оценка эффективности обогащения финального концентрата
final_pred = grid_lr_final.predict(final_test_X)
final_smape = smape(final_test_y, final_pred)

print(f'Итоговое sMAPE модели: {0.25 * rougher_smape + 0.75 * final_smape:.2f}')
# Out:
# Итоговое sMAPE модели: 7.01

# %% [markdown]
# ### 3.4. Проверка на адекватность.
# Сравним предсказание модели и предсказания наивного регрессора.

# %%
# Наивный регрессор для оценки эффективности обогащения чернового концентрата
dummy_rougher = DummyRegressor(strategy='mean')
dummy_rougher.fit(rougher_train_X, rougher_train_y)
dummy_rougher_pred = dummy_rougher.predict(rougher_test_X)
dummy_rougher_smape = smape(rougher_test_y, dummy_rougher_pred)

# Наивный регрессор для оценки эффективности обогащения финального концентрата
dummy_final = DummyRegressor(strategy='mean')
dummy_final.fit(final_train_X, final_train_y)
dummy_final_pred = dummy_final.predict(final_test_X)
dummy_final_smape = smape(final_test_y, dummy_final_pred)

print(f'Итоговое sMAPE наивного регрессора: {0.25 * dummy_rougher_smape + 0.75 * dummy_final_smape:.2f}')
# Out:
# Итоговое sMAPE наивного регрессора: 8.47

# %% [markdown]
# ### Вывод
# Для предсказания эффективности обогащения чернового и финального концентрата были проверны модели линейной регрессии, случайного леса и к-ближайших соседей. Лучшие значения метрики sMAPE для эффективности обогащения чернового концентрата показала модель случайного леса, а для финального - линейной регрессии, которые и были приняты для проверки на тестовой выборке. Значение итогового sMAPE лучше, чем предсказания наивного регрессора.

# %% [markdown]
# ## Заключение
# В исследовании были изучены данные процесса обогащения золотосодержащей руды. Исходные данные содержат достаточно большое количество признаков (86), при этом в тестовой выборке отсутствуют признаки (34 столбца), которые неизвестны в процессе обогащения. Сильная корреляция между эффективностью обогащения финального концентрата и остальными признаками отсутствует. Есть прямая корреляция между эффективностью обогащения чернового концентрата и содержанием в нем серебра, что связано с возрастанием концентрации серебра на флотации. Заметно наличие корреляции между концентрациями золота, серебра и свинца в сырье, а также между серебром и свинцом на входе и в хвостах. Значения эффективности обогащения соответствуют расчетным.
#
# Исследовательский анализ показал возрастание концентрации металлов в смеси в процессе обогащения и снижение дисперсии распределений концентрации. Плотность вероятности распределений суммарной концентрации металлов на разных стадиях показывает утолщение в районе нуля. Решено исключить аномальные значения из обучающей выборки в количестве 591 строки. Концентрация золота возрастает на всех этапах процесса. Концентрация серебра возрастает на этапе флотации, а дальше снижается. Концентрация свинца растет до второй стадии очистки. На второй стадии очистки концентрация свинца почти не меняется, но снижается дисперсия. Распределения размера гранул в тренировочной и тестовой выборках очень похожи, поэтому данный параметр не будет искажать результаты оценки модели.
#
# Для предсказания эффективности обогащения чернового и финального концентрата были проверны модели линейной регрессии, случайного леса и к-ближайших соседей. Лучшие значения метрики sMAPE для эффективности обогащения чернового концентрата показала модель случайного леса, а для финального - линейной регрессии, которые и были приняты для проверки на тестовой выборке. Значение итогового sMAPE равно 7.01, что лучше оценки наивного регрессора, предсказывающего среднее значение (8.47).
#
# Таким образом, финальная модель подходит в качестве прототипа для оценки эффективности обогащения золотосодержащей руды.
